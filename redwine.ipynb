# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("winequality-red.csv", header = None)

# %%
dataset
# Out:
#                  0                 1            2               3   \
# 0     fixed acidity  volatile acidity  citric acid  residual sugar
# 1               7.4               0.7          0.0             1.9
# 2               7.8              0.88          0.0             2.6
# 3               7.8              0.76         0.04             2.3
# 4              11.2              0.28         0.56             1.9
# 5               7.4               0.7          0.0             1.9
# 6               7.4              0.66          0.0             1.8
# 7               7.9               0.6         0.06             1.6
# 8               7.3              0.65          0.0             1.2
# 9               7.8              0.58         0.02             2.0
# 10              7.5               0.5         0.36             6.1
# 11              6.7              0.58         0.08             1.8
# 12              7.5               0.5         0.36             6.1
# ...

# %%
len(dataset)
# Out:
# 1600

# %%
dataset.shape
# Out:
# (1600, 12)

# %%
datasets = dataset[1:]
datasets
# Out:
#         0      1     2     3                     4     5      6   \
# 1      7.4    0.7   0.0   1.9                 0.076  11.0   34.0
# 2      7.8   0.88   0.0   2.6                 0.098  25.0   67.0
# 3      7.8   0.76  0.04   2.3                 0.092  15.0   54.0
# 4     11.2   0.28  0.56   1.9                 0.075  17.0   60.0
# 5      7.4    0.7   0.0   1.9                 0.076  11.0   34.0
# 6      7.4   0.66   0.0   1.8                 0.075  13.0   40.0
# 7      7.9    0.6  0.06   1.6                 0.069  15.0   59.0
# 8      7.3   0.65   0.0   1.2                 0.065  15.0   21.0
# 9      7.8   0.58  0.02   2.0                 0.073   9.0   18.0
# 10     7.5    0.5  0.36   6.1                 0.071  17.0  102.0
# 11     6.7   0.58  0.08   1.8   0.09699999999999999  15.0   65.0
# 12     7.5    0.5  0.36   6.1                 0.071  17.0  102.0
# 13     5.6  0.615   0.0   1.6   0.08900000000000001  16.0   59.0
# ...

# %%
dataset = np.array(datasets,dtype = float)

# %%
#from sklearn.model_selection import train_test_split

# %%
#X_train, X_test, y_train, y_test = train_test_split(dataset, datasets, test_size=0.2)

# %%
#print (X_train.shape, y_train.shape)
#print (X_test.shape, y_test.shape)
# Out:
# (171, 10) (171, 10)
# (43, 10) (43, 10)

# %%
datasets = np.array(dataset)
datasets
# Out:
# array([[ 7.4  ,  0.7  ,  0.   , ...,  0.56 ,  9.4  ,  5.   ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  0.68 ,  9.8  ,  5.   ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  0.65 ,  9.8  ,  5.   ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ...,  0.75 , 11.   ,  6.   ],
#        [ 5.9  ,  0.645,  0.12 , ...,  0.71 , 10.2  ,  5.   ],
#        [ 6.   ,  0.31 ,  0.47 , ...,  0.66 , 11.   ,  6.   ]])

# %%
train_data = datasets[:1190,:11]
train_data
# Out:
# array([[ 7.4  ,  0.7  ,  0.   , ...,  3.51 ,  0.56 ,  9.4  ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  3.2  ,  0.68 ,  9.8  ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  3.26 ,  0.65 ,  9.8  ],
#        ...,
#        [ 7.   ,  0.43 ,  0.3  , ...,  3.33 ,  0.46 , 11.9  ],
#        [ 6.7  ,  0.64 ,  0.23 , ...,  3.36 ,  0.7  , 10.9  ],
#        [ 8.8  ,  0.955,  0.05 , ...,  3.3  ,  0.44 ,  9.6  ]])

# %%
train_label = datasets[:1190,-1]
train_label
# Out:
# array([5., 5., 5., ..., 6., 5., 4.])

# %%
test_data = datasets[1190:,:11]
test_data
# Out:
# array([[ 9.1  ,  0.4  ,  0.57 , ...,  3.28 ,  0.57 , 12.5  ],
#        [ 6.5  ,  0.885,  0.   , ...,  3.56 ,  0.51 , 10.8  ],
#        [ 7.2  ,  0.25 ,  0.37 , ...,  3.52 ,  0.8  , 12.4  ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ...,
#        6., 5., 6., 5., 5., 5., 5., 5., 6., 5., 5., 5., 5., 5., 6., 5., 6.,
#        5., 5., 6., 4., 6., 5., 5., 6., 6., 4., 5., 6., 5., 5., 3., 5., 5.,
#        6., 6., 6., 6., 5., 5., 5., 5., 5., 5., 5., 5., 5., 6., 5., 5., 5.,
# ...

# %%
mean = train_data.mean(axis=0) 
train_data -= mean
std = train_data.std(axis=0) 
train_data /= std
test_data -= mean 
test_data /= std

# %%
k=5
num_val_samples = len(train_data) // k 
num_epochs = 100

# %%
num_epochs=200

for i in range(k): 
    print('processing fold #', i)
    val_data = train_data[i * num_val_samples: (i + 1) * num_val_samples] 
    val_target = train_label[i * num_val_samples: (i + 1) * num_val_samples]
# Out:
# processing fold # 0
# processing fold # 1
# processing fold # 2
# processing fold # 3
# processing fold # 4

# %%
train_data[1]
# Out:
# array([-0.4686204 ,  2.02133234, -1.49368645,  0.02674222,  0.18173102,
#         0.95222038,  0.59138099, -0.14337168, -0.62967217,  0.07854254,
#        -0.53269996])

# %%
from keras import models
from keras import layers

# %%
model = models.Sequential()

# %%
model.add(layers.Dense(20, activation='relu',input_shape=(train_data.shape[1],)))
model.add(layers.Dense(20, activation='relu'))
model.add(layers.Dense(1,))

# %%
model.compile(optimizer='rmsprop', loss='mse', metrics=['acc'])

# %%
history = model.fit(val_data,val_target,epochs=30,batch_size=10)
# Out:
# Epoch 1/30
# 238/238 [==============================] - 0s 1ms/step - loss: 30.6138 - acc: 0.0000e+00
# Epoch 2/30
# 238/238 [==============================] - 0s 185us/step - loss: 23.0866 - acc: 0.0000e+00
# Epoch 3/30
# 238/238 [==============================] - 0s 168us/step - loss: 16.3809 - acc: 0.0000e+00
# Epoch 4/30
# 238/238 [==============================] - 0s 185us/step - loss: 10.4667 - acc: 0.0336
# Epoch 5/30
# 238/238 [==============================] - 0s 202us/step - loss: 6.1448 - acc: 0.0966
# Epoch 6/30
# 238/238 [==============================] - 0s 218us/step - loss: 3.9598 - acc: 0.1387
# Epoch 7/30
# 238/238 [==============================] - 0s 202us/step - loss: 3.1350 - acc: 0.1933
# Epoch 8/30
# 238/238 [==============================] - 0s 185us/step - loss: 2.6155 - acc: 0.2185
# Epoch 9/30
# 238/238 [==============================] - 0s 185us/step - loss: 2.1886 - acc: 0.2647
# Epoch 10/30
# ...

# %%
a = model.evaluate(val_data,val_target)
# Out:
# 238/238 [==============================] - 0s 353us/step

# %%
a
# Out:
# [0.4476714219365801, 0.5546218487394958]

# %%
print(val_target[1])
# Out:
# 7.0

# %%
accuracy = history.history['acc']
epochs = range(1,len(acc)+1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-c5c1a91239c5> in <module>
#       1 accuracy = history.history['acc']
# ----> 2 epochs = range(1,len(acc)+1)
#
# NameError: name 'acc' is not defined

# %%
loss = history.history['loss']
epoch = range(1, len(loss)+1)

# %%
import matplotlib.pyplot as plt
plt.plot(epoch,accuracy, 'r')

# %%
plt.plot(epoch,loss, 'g')
